# %%
import numpy as nm
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv(r'C:\Users\test01\Desktop\insurance.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
dataset.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
x=dataset.iloc[:,:-1].values

# %%
x
# Out:
# array([[19, 'female', 27.9, 0, 'yes', 'southwest'],
#        [18, 'male', 33.77, 1, 'no', 'southeast'],
#        [28, 'male', 33.0, 3, 'no', 'southeast'],
#        ...,
#        [18, 'female', 36.85, 0, 'no', 'southeast'],
#        [21, 'female', 25.8, 0, 'no', 'southwest'],
#        [61, 'female', 29.07, 0, 'yes', 'northwest']], dtype=object)

# %%
y=dataset.iloc[:,-1].values

# %%
y
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
import seaborn as sns

# %%
sns.heatmap(dataset.corr(),annot=True)

# %%
dataset.drop(columns=['children'],inplace=True)

# %%
dataset
# Out:
#       age     sex     bmi smoker     region      charges
# 0      19  female  27.900    yes  southwest  16884.92400
# 1      18    male  33.770     no  southeast   1725.55230
# 2      28    male  33.000     no  southeast   4449.46200
# 3      33    male  22.705     no  northwest  21984.47061
# 4      32    male  28.880     no  northwest   3866.85520
# 5      31  female  25.740     no  southeast   3756.62160
# 6      46  female  33.440     no  southeast   8240.58960
# 7      37  female  27.740     no  northwest   7281.50560
# 8      37    male  29.830     no  northeast   6406.41070
# 9      60  female  25.840     no  northwest  28923.13692
# 10     25    male  26.220     no  northeast   2721.32080
# 11     62  female  26.290    yes  southeast  27808.72510
# 12     23    male  34.400     no  southwest   1826.84300
# 13     56  female  39.820     no  southeast  11090.71780
# 14     27    male  42.130    yes  southeast  39611.75770
# ...

# %%
x=dataset.iloc[:,:-1].values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
x
# Out:
# array([[19, 'female', 27.9, 'yes', 'southwest'],
#        [18, 'male', 33.77, 'no', 'southeast'],
#        [28, 'male', 33.0, 'no', 'southeast'],
#        ...,
#        [18, 'female', 36.85, 'no', 'southeast'],
#        [21, 'female', 25.8, 'no', 'southwest'],
#        [61, 'female', 29.07, 'yes', 'northwest']], dtype=object)

# %%
obj=LabelEncoder()

# %%
x[:,1]=obj.fit_transform(x[:,1])

# %%
x
# Out:
# array([[19, 0, 27.9, 'yes', 'southwest'],
#        [18, 1, 33.77, 'no', 'southeast'],
#        [28, 1, 33.0, 'no', 'southeast'],
#        ...,
#        [18, 0, 36.85, 'no', 'southeast'],
#        [21, 0, 25.8, 'no', 'southwest'],
#        [61, 0, 29.07, 'yes', 'northwest']], dtype=object)

# %%
x[:,3]=obj.fit_transform(x[:,3])

# %%
x
# Out:
# array([[19, 0, 27.9, 1, 'southwest'],
#        [18, 1, 33.77, 0, 'southeast'],
#        [28, 1, 33.0, 0, 'southeast'],
#        ...,
#        [18, 0, 36.85, 0, 'southeast'],
#        [21, 0, 25.8, 0, 'southwest'],
#        [61, 0, 29.07, 1, 'northwest']], dtype=object)

# %%
x[:,4]=obj.fit_transform(x[:,4])

# %%
x
# Out:
# array([[19, 0, 27.9, 1, 3],
#        [18, 1, 33.77, 0, 2],
#        [28, 1, 33.0, 0, 2],
#        ...,
#        [18, 0, 36.85, 0, 2],
#        [21, 0, 25.8, 0, 3],
#        [61, 0, 29.07, 1, 1]], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
obj1=OneHotEncoder(categorical_features=[-1])

# %%
x=obj1.fit_transform(x).toarray()

# %%
x=x[:,1:]

# %%
x
# Out:
# array([[ 0.  ,  0.  ,  1.  , ...,  0.  , 27.9 ,  1.  ],
#        [ 0.  ,  1.  ,  0.  , ...,  1.  , 33.77,  0.  ],
#        [ 0.  ,  1.  ,  0.  , ...,  1.  , 33.  ,  0.  ],
#        ...,
#        [ 0.  ,  1.  ,  0.  , ...,  0.  , 36.85,  0.  ],
#        [ 0.  ,  0.  ,  1.  , ...,  0.  , 25.8 ,  0.  ],
#        [ 1.  ,  0.  ,  0.  , ...,  0.  , 29.07,  1.  ]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train
# Out:
# array([[ 1.  ,  0.  ,  0.  , ...,  0.  , 26.6 ,  0.  ],
#        [ 0.  ,  0.  ,  1.  , ...,  1.  , 21.4 ,  0.  ],
#        [ 0.  ,  1.  ,  0.  , ...,  1.  , 37.29,  0.  ],
#        ...,
#        [ 0.  ,  0.  ,  0.  , ...,  0.  , 34.96,  1.  ],
#        [ 0.  ,  1.  ,  0.  , ...,  0.  , 22.22,  1.  ],
#        [ 0.  ,  1.  ,  0.  , ...,  1.  , 27.94,  0.  ]])

# %%
x_test
# Out:
# array([[ 1.   ,  0.   ,  0.   , ...,  1.   , 35.53 ,  0.   ],
#        [ 1.   ,  0.   ,  0.   , ...,  1.   , 31.54 ,  0.   ],
#        [ 0.   ,  0.   ,  1.   , ...,  1.   , 37.   ,  0.   ],
#        ...,
#        [ 0.   ,  1.   ,  0.   , ...,  1.   , 38.94 ,  1.   ],
#        [ 1.   ,  0.   ,  0.   , ...,  0.   , 36.575,  0.   ],
#        [ 0.   ,  0.   ,  0.   , ...,  0.   , 26.125,  0.   ]])

# %%
y_train
# Out:
# array([10355.641 , 10065.413 ,  1141.4451, ..., 44641.1974, 19444.2658,
#        11554.2236])

# %%
y_test
# Out:
# array([ 1646.4297 , 11353.2276 ,  8798.593  , 10381.4787 ,  2103.08   ,
#        38746.3551 ,  9304.7019 , 11658.11505,  3070.8087 , 19539.243  ,
#        12629.8967 , 11538.421  ,  6338.0756 ,  7050.642  ,  1137.4697 ,
#         8968.33   , 21984.47061,  6414.178  , 28287.89766, 13462.52   ,
#         9722.7695 , 40932.4295 ,  8026.6666 ,  8444.474  ,  2203.47185,
#         6664.68595,  8606.2174 ,  8283.6807 ,  5375.038  ,  3645.0894 ,
#        11674.13   , 11737.84884, 24873.3849 , 33750.2918 , 24180.9335 ,
#         9863.4718 , 36837.467  , 17942.106  , 11856.4115 , 39725.51805,
#         4349.462  , 11743.9341 , 19749.38338, 12347.172  ,  4931.647  ,
#        30259.99556, 27724.28875, 34672.1472 ,  9644.2525 , 14394.39815,
#        12557.6053 , 11881.358  ,  2352.96845,  9101.798  , 17178.6824 ,
#         3994.1778 , 40941.2854 , 12644.589  , 22395.74424,  1149.3959 ,
#         3366.6697 , 13143.33665, 18328.2381 ,  2690.1138 , 12741.16745,
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
from sklearn.linear_model import LinearRegression

# %%
li=LinearRegression()

# %%
li.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pre=li.predict(x_test)

# %%
y_pre
# Out:
# array([ 4.88354719e+03,  1.34129772e+04,  1.30801975e+04,  1.24746273e+04,
#         6.09623924e+02,  3.13805181e+04,  1.25428657e+04,  1.27325785e+04,
#         4.20569341e+03,  2.98532509e+04,  1.14260584e+04,  1.71868802e+04,
#         8.29923251e+03,  8.39981992e+03,  3.54864030e+03,  1.01201309e+04,
#         4.37658433e+03,  6.17458031e+03,  1.50213209e+04,  1.49137511e+04,
#         1.29812459e+04,  3.21114030e+04,  9.56602870e+03,  9.47953592e+03,
#         3.40931506e+03,  8.27414496e+03,  8.76441650e+03,  1.11558354e+04,
#         7.32939948e+03,  4.79711499e+03,  1.42001375e+04,  5.47681768e+03,
#         3.37993448e+04,  2.74882289e+04,  3.25167375e+04,  1.00597222e+04,
#         3.08764367e+04,  2.54672501e+04,  1.55762331e+04,  3.39581536e+04,
#         5.88568383e+03,  1.45871435e+04,  9.90459922e+03,  1.51779736e+04,
#         3.82406239e+03,  1.35508122e+04,  4.34787286e+03,  2.90117639e+04,
# ...

# %%
y_test
# Out:
# array([ 1646.4297 , 11353.2276 ,  8798.593  , 10381.4787 ,  2103.08   ,
#        38746.3551 ,  9304.7019 , 11658.11505,  3070.8087 , 19539.243  ,
#        12629.8967 , 11538.421  ,  6338.0756 ,  7050.642  ,  1137.4697 ,
#         8968.33   , 21984.47061,  6414.178  , 28287.89766, 13462.52   ,
#         9722.7695 , 40932.4295 ,  8026.6666 ,  8444.474  ,  2203.47185,
#         6664.68595,  8606.2174 ,  8283.6807 ,  5375.038  ,  3645.0894 ,
#        11674.13   , 11737.84884, 24873.3849 , 33750.2918 , 24180.9335 ,
#         9863.4718 , 36837.467  , 17942.106  , 11856.4115 , 39725.51805,
#         4349.462  , 11743.9341 , 19749.38338, 12347.172  ,  4931.647  ,
#        30259.99556, 27724.28875, 34672.1472 ,  9644.2525 , 14394.39815,
#        12557.6053 , 11881.358  ,  2352.96845,  9101.798  , 17178.6824 ,
#         3994.1778 , 40941.2854 , 12644.589  , 22395.74424,  1149.3959 ,
#         3366.6697 , 13143.33665, 18328.2381 ,  2690.1138 , 12741.16745,
# ...

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pre)
# Out:
# 0.757983108927623

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
sns.heatmap(dataset.corr(),annot=True)

# %%
x_data=pd.DataFrame(x)

# %%
x
# Out:
# array([[ 0.  ,  0.  ,  1.  , ...,  0.  , 27.9 ,  1.  ],
#        [ 0.  ,  1.  ,  0.  , ...,  1.  , 33.77,  0.  ],
#        [ 0.  ,  1.  ,  0.  , ...,  1.  , 33.  ,  0.  ],
#        ...,
#        [ 0.  ,  1.  ,  0.  , ...,  0.  , 36.85,  0.  ],
#        [ 0.  ,  0.  ,  1.  , ...,  0.  , 25.8 ,  0.  ],
#        [ 1.  ,  0.  ,  0.  , ...,  0.  , 29.07,  1.  ]])

# %%
x_data
# Out:
#         0    1    2     3    4       5    6
# 0     0.0  0.0  1.0  19.0  0.0  27.900  1.0
# 1     0.0  1.0  0.0  18.0  1.0  33.770  0.0
# 2     0.0  1.0  0.0  28.0  1.0  33.000  0.0
# 3     1.0  0.0  0.0  33.0  1.0  22.705  0.0
# 4     1.0  0.0  0.0  32.0  1.0  28.880  0.0
# 5     0.0  1.0  0.0  31.0  0.0  25.740  0.0
# 6     0.0  1.0  0.0  46.0  0.0  33.440  0.0
# 7     1.0  0.0  0.0  37.0  0.0  27.740  0.0
# 8     0.0  0.0  0.0  37.0  1.0  29.830  0.0
# 9     1.0  0.0  0.0  60.0  0.0  25.840  0.0
# 10    0.0  0.0  0.0  25.0  1.0  26.220  0.0
# 11    0.0  1.0  0.0  62.0  0.0  26.290  1.0
# 12    0.0  0.0  1.0  23.0  1.0  34.400  0.0
# 13    0.0  1.0  0.0  56.0  0.0  39.820  0.0
# 14    0.0  1.0  0.0  27.0  1.0  42.130  1.0
# 15    0.0  0.0  1.0  19.0  1.0  24.600  0.0
# 16    0.0  0.0  0.0  52.0  0.0  30.780  0.0
# 17    0.0  0.0  0.0  23.0  1.0  23.845  0.0
# 18    0.0  0.0  1.0  56.0  1.0  40.300  0.0
# 19    0.0  0.0  1.0  30.0  1.0  35.300  1.0
# ...

# %%
sns.heatmap(x_data.corr())

# %%
import dlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d25f48e861da> in <module>
# ----> 1 import dlib
#
# ModuleNotFoundError: No module named 'dlib'

# %%
import cv2

# %%
import scipy

# %%
import
