# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as nm

# %%
dataset=pd.read_csv(r'C:\Users\test01\Desktop\50_Startups.csv')

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11              NaN     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dataset=dataset.dropna()
#dataset=dataset.fillna(dataset['State'].mode()[0])

# %% [markdown]
# # corelation

# %%
dataset.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.256192         0.730742  0.976830
# Administration    0.256192        1.000000        -0.031138  0.212211
# Marketing Spend   0.730742       -0.031138         1.000000  0.751265
# Profit            0.976830        0.212211         0.751265  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(dataset.corr(),annot=True)

# %%
dataset=dataset.drop(columns=['Administration'])

# %%
dataset
# Out:
#     R&D Spend  Marketing Spend       State     Profit
# 0   165349.20        471784.10    New York  192261.83
# 1   162597.70        443898.53  California  191792.06
# 2   153441.51        407934.54     Florida  191050.39
# 3   144372.41        383199.62    New York  182901.99
# 4   142107.34        366168.42     Florida  166187.94
# 5   131876.90        362861.36    New York  156991.12
# 6   134615.46        127716.82  California  156122.51
# 7   130298.13        323876.68     Florida  155752.60
# 8   120542.52        311613.29    New York  152211.77
# 9   123334.88        304981.62  California  149759.96
# 11  100671.96        249744.55  California  144259.40
# 12   93863.75        249839.44     Florida  141585.52
# 13   91992.39        252664.93  California  134307.35
# 14  119943.24        256512.92     Florida  132602.65
# 16   78013.11        264346.06  California  126992.93
# 17   94657.16        282574.31    New York  125370.37
# ...

# %%
x=dataset.iloc[:,0:-1].values

# %%
x
# Out:
# array([[165349.2, 471784.1, 'New York'],
#        [162597.7, 443898.53, 'California'],
#        [153441.51, 407934.54, 'Florida'],
#        [144372.41, 383199.62, 'New York'],
#        [142107.34, 366168.42, 'Florida'],
#        [131876.9, 362861.36, 'New York'],
#        [134615.46, 127716.82, 'California'],
#        [130298.13, 323876.68, 'Florida'],
#        [120542.52, 311613.29, 'New York'],
#        [123334.88, 304981.62, 'California'],
#        [100671.96, 249744.55, 'California'],
#        [93863.75, 249839.44, 'Florida'],
#        [91992.39, 252664.93, 'California'],
#        [119943.24, 256512.92, 'Florida'],
#        [78013.11, 264346.06, 'California'],
#        [94657.16, 282574.31, 'New York'],
#        [91749.16, 294919.57, 'Florida'],
#        [86419.7, 0.0, 'New York'],
#        [76253.86, 298664.47, 'California'],
#        [78389.47, 299737.29, 'New York'],
#        [73994.56, 303319.26, 'Florida'],
#        [67532.53, 304768.73, 'Florida'],
# ...

# %%
y=dataset.iloc[:,-1].values

# %%
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 144259.4 , 141585.52,
#        134307.35, 132602.65, 126992.93, 125370.37, 124266.9 , 122776.86,
#        118474.03, 111313.02, 110352.25, 108733.99, 108552.04, 107404.34,
#        105733.54, 105008.31, 103282.38, 101004.64,  99937.59,  97483.56,
#         97427.84,  96778.92,  96712.8 ,  96479.51,  89949.14,  81229.06,
#         81005.76,  78239.91,  77798.83,  71498.49,  69758.98,  65200.33,
#         64926.08,  49490.75,  42559.73,  35673.41,  14681.4 ])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
obj=LabelEncoder()

# %%
x[:,2]=obj.fit_transform(x[:,2])

# %%
x
# Out:
# array([[165349.2, 471784.1, 2],
#        [162597.7, 443898.53, 0],
#        [153441.51, 407934.54, 1],
#        [144372.41, 383199.62, 2],
#        [142107.34, 366168.42, 1],
#        [131876.9, 362861.36, 2],
#        [134615.46, 127716.82, 0],
#        [130298.13, 323876.68, 1],
#        [120542.52, 311613.29, 2],
#        [123334.88, 304981.62, 0],
#        [100671.96, 249744.55, 0],
#        [93863.75, 249839.44, 1],
#        [91992.39, 252664.93, 0],
#        [119943.24, 256512.92, 1],
#        [78013.11, 264346.06, 0],
#        [94657.16, 282574.31, 2],
#        [91749.16, 294919.57, 1],
#        [86419.7, 0.0, 2],
#        [76253.86, 298664.47, 0],
#        [78389.47, 299737.29, 2],
#        [73994.56, 303319.26, 1],
#        [67532.53, 304768.73, 1],
#        [77044.01, 140574.81, 2],
#        [64664.71, 137962.62, 0],
#        [75328.87, 134050.07, 1],
#        [72107.6, 353183.81, 2],
#        [66051.52, 118148.2, 1],
#        [65605.48, 107138.38, 2],
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
oh=OneHotEncoder(categorical_features=[2])

# %%
x=oh.fit_transform(x).toarray()

# %%
x
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.6534920e+05,
#         4.7178410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6259770e+05,
#         4.4389853e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.5344151e+05,
#         4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.4437241e+05,
#         3.8319962e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.4210734e+05,
#         3.6616842e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.3187690e+05,
#         3.6286136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3461546e+05,
#         1.2771682e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.3029813e+05,
#         3.2387668e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.2054252e+05,
#         3.1161329e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.2333488e+05,
#         3.0498162e+05],
# ...

# %%
x=x[:,1:]

# %%
x
# Out:
# array([[0.0000000e+00, 1.0000000e+00, 1.6534920e+05, 4.7178410e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.6259770e+05, 4.4389853e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.5344151e+05, 4.0793454e+05],
#        [0.0000000e+00, 1.0000000e+00, 1.4437241e+05, 3.8319962e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.4210734e+05, 3.6616842e+05],
#        [0.0000000e+00, 1.0000000e+00, 1.3187690e+05, 3.6286136e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.3461546e+05, 1.2771682e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.3029813e+05, 3.2387668e+05],
#        [0.0000000e+00, 1.0000000e+00, 1.2054252e+05, 3.1161329e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.2333488e+05, 3.0498162e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0067196e+05, 2.4974455e+05],
#        [1.0000000e+00, 0.0000000e+00, 9.3863750e+04, 2.4983944e+05],
#        [0.0000000e+00, 0.0000000e+00, 9.1992390e+04, 2.5266493e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.1994324e+05, 2.5651292e+05],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 1.1994324e+05, 2.5651292e+05],
#        [0.0000000e+00, 1.0000000e+00, 1.0002300e+03, 1.9039300e+03],
#        [0.0000000e+00, 0.0000000e+00, 3.8558510e+04, 1.7499930e+05],
#        [0.0000000e+00, 1.0000000e+00, 1.3187690e+05, 3.6286136e+05],
#        [0.0000000e+00, 0.0000000e+00, 9.1992390e+04, 2.5266493e+05],
#        [0.0000000e+00, 0.0000000e+00, 4.6426070e+04, 2.1079767e+05],
#        [1.0000000e+00, 0.0000000e+00, 7.3994560e+04, 3.0331926e+05],
#        [0.0000000e+00, 1.0000000e+00, 6.1136380e+04, 8.8218230e+04],
#        [1.0000000e+00, 0.0000000e+00, 9.3863750e+04, 2.4983944e+05],
#        [1.0000000e+00, 0.0000000e+00, 5.5493950e+04, 2.1463481e+05],
#        [0.0000000e+00, 0.0000000e+00, 6.4664710e+04, 1.3796262e+05],
#        [0.0000000e+00, 0.0000000e+00, 7.8013110e+04, 2.6434606e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.3154600e+03, 2.9711446e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.4210734e+05, 3.6616842e+05],
# ...

# %%
y_train
# Out:
# array([132602.65,  64926.08,  81005.76, 156991.12, 134307.35,  96712.8 ,
#        110352.25,  97483.56, 141585.52,  96778.92, 107404.34, 126992.93,
#         49490.75, 166187.94, 149759.96, 156122.51, 125370.37,  71498.49,
#        103282.38, 192261.83,  97427.84,  78239.91, 182901.99,  35673.41,
#         77798.83,  81229.06, 101004.64, 118474.03,  42559.73,  96479.51,
#        108552.04, 155752.6 , 108733.99, 152211.77, 122776.86,  65200.33,
#         99937.59])

# %%
x_test
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 4.4069950e+04, 1.9702942e+05],
#        [0.0000000e+00, 1.0000000e+00, 7.8389470e+04, 2.9973729e+05],
#        [0.0000000e+00, 1.0000000e+00, 7.2107600e+04, 3.5318381e+05],
#        [0.0000000e+00, 1.0000000e+00, 1.5505730e+04, 3.5534170e+04],
#        [1.0000000e+00, 0.0000000e+00, 9.1749160e+04, 2.9491957e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0067196e+05, 2.4974455e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.6259770e+05, 4.4389853e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.5344151e+05, 4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.5173060e+04],
#        [1.0000000e+00, 0.0000000e+00, 7.5328870e+04, 1.3405007e+05]])

# %%
y_test
# Out:
# array([ 89949.14, 111313.02, 105008.31,  69758.98, 124266.9 , 144259.4 ,
#        191792.06, 191050.39,  14681.4 , 105733.54])

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %% [markdown]
# # Train the model

# %%
from sklearn.linear_model import LinearRegression

# %%
li=LinearRegression()

# %%
li.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# # Test the Model

# %%
y_pred=li.predict(x_test)

# %%
y_pred
# Out:
# array([ 90167.01420471, 120623.64450445, 117678.34459225,  63447.95254483,
#        126415.63910279, 135217.80852031, 189234.79163244, 177443.01121399,
#         51251.21933748, 108302.28205166])

# %%
y_test
# Out:
# array([ 89949.14, 111313.02, 105008.31,  69758.98, 124266.9 , 144259.4 ,
#        191792.06, 191050.39,  14681.4 , 105733.54])

# %%
#li.predict([[0,1,152645.2,152547.23,387525.23]])

# %%
li.intercept_
# Out:
# 49686.019890157615

# %%
li.coef_
# Out:
# array([-3.55351769e+03,  6.89720245e+02,  7.63652563e-01,  3.46489577e-02])

# %% [markdown]
# # Evaluating Model Performance

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.925307449850453
